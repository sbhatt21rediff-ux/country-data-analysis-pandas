# %%
##Questions##

# %%
#which country has the highest population

#what is the capital of the country with highest population

#which country has the least population#what is the capital of the country with least population

#give me top 5 countries with highest democratic score#how many total regions are there

#how many countries lie in Eastern Europe region

#how many countries are there whoes political leaders are unknown

#how many country have Republic in their full name

#which country in african region has highest population

#who is the political leader of the 2nd highest populated country

# %%
import numpy as np

import pandas as pd

# %%
url = "https://raw.githubusercontent.com/sbhatt21rediff-ux/country-data-analysis-pandas/refs/heads/main/Countries%20(1).csv"
data = pd.read_csv(url)

# %%
data
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
##Data Preprocessing##

# %%
data.shape
# Out:
# (194, 64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
data.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
highest_pop=data[data["population"]==data['population'].max()]['country']
highest_pop
# Out:
# 75    India
# Name: country, dtype: object

# %% [markdown]
# # New section

# %%
highest_pop_cap=data[data["population"]==data['population'].max()]["capital_city"]
highest_pop_cap
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
min_pop_cap=data[data['population']==data['population'].min()]['capital_city']
min_pop_cap
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
top_5_demo=data.nlargest(5,['democracy_score'])[['country','democracy_score']]
top_5_demo
# Out:
#          country  democracy_score
# 127       Norway             9.87
# 74       Iceland             9.58
# 164       Sweden             9.39
# 122  New Zealand             9.26
# 46       Denmark             9.22

# %%
top_5_demo_2option=data.sort_values(by='democracy_score',ascending=False).head(5)[['country','democracy_score']]
top_5_demo_2option
# Out:
#          country  democracy_score
# 127       Norway             9.87
# 74       Iceland             9.58
# 164       Sweden             9.39
# 122  New Zealand             9.26
# 46       Denmark             9.22

# %%
total_regions=data['region'].value_counts().count()
total_regions
# Out:
# np.int64(22)

# %%
eastern_europe_count =data[data['region']=='Eastern Europe']['country']
eastern_europe_count
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: object

# %%
unknown_leaders=data[data['political_leader'].isna()]['country'].count()
unknown_leaders
# Out:
# np.int64(7)

# %%
republic_count=data['country_long'].str.contains("Republic",case=False,na=False).sum()
republic_count
# Out:
# np.int64(125)

# %%
count=0
def   countt(txt):
  global count
  if "republic" in str(txt).lower():
    count+=1
  return txt

# %%
data['country_long'].apply(countt)
print(count)
# Out:
# 125

# %%
African_Region=data[data["continent"]=="Africa"]
African_Region[African_Region['population']==African_Region['population'].max()]['country']
# Out:
# 125    Nigeria
# Name: country, dtype: object

# %%
second_highest_leader=data[data['population']==data['population'].nlargest(2).iloc[1]]["political_leader"]
second_highest_leader
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object
